# %%
from os.path import exists
import pandas as pd 
import numpy as np

# %%
from upgini import FeaturesEnricher, SearchKey
from upgini.metadata import CVType

from catboost import CatBoostRegressor
from catboost.utils import eval_metric

# %%
url = 'train.csv.zip' if exists('train.csv.zip') else 'https://github.com/upgini/upgini/raw/main/notebooks/train.csv.zip'
df = pd.read_csv(url)
df.head()
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10

# %%
df = df.sample(n=19000, random_state=0)

df['store'] = df['store'].astype(str)
df['item'] = df['item'].astype(str)

df['date'] = pd.to_datetime(df['date'])

df.sort_values('date', inplace=True)
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#         date store item  sales
# 0 2013-01-01     7    5      5
# 1 2013-01-01     4    9     19
# 2 2013-01-01     1   33     37
# 3 2013-01-01     3   41     14
# 4 2013-01-01     5   24     26

# %%
train = df[df['date'] < '2017-01-01']
test = df[df['date'] >= '2017-01-01']

# %%
train_features = train.drop(columns=['sales'])
train_target = train['sales']

test_features = test.drop(columns=['sales'])
test_target = test['sales']

# %%
enricher = FeaturesEnricher(
    search_keys ={
        'date':SearchKey.DATE,
    },
    cv = CVType.time_series
)
enricher.fit(train_features, train_target, eval_set=[(test_features, test_target)])
# Out:
# WARNING: You have started the search with the DATE key only. Try to add the COUNTRY and/or POSTAL_CODE keys to your dataset so that the search engine gets access to the additional data sources. Get details on https://github.com/upgini/upgini#2--choose-one-or-multiple-columns-as-a-search-keys
# Detected task type: ModelTaskType.REGRESSION
# <table><tr><th style='font-weight:bold'>Column name</th><th style='font-weight:bold'>Status</th><th style='font-weight:bold'>Description</th></tr><tr><td>target</td><td style='background-color:#DAF7A6;color:black'>All valid</td><td>All values in this column are good to go</td></tr><tr><td>date</td><td style='background-color:#DAF7A6;color:black'>All valid</td><td>All values in this column are good to go</td></tr></table>
# Running search request with search_id=cc6a34ed-fcea-4608-aff4-ed5ab60d4ecd
# We'll send email notification once it's completed, just use your personal api_key from profile.upgini.com
# Done
#
#
# 28 relevant feature(s) found with the search keys: ['date'].
#                               feature_name  shap_value  coverage %       type
# 0                                     item    0.487726       100.0  CHARACTER
# 1                                    store    0.172106       100.0  CHARACTER
# 2                 f_weather_pca_0_94efd18d    0.056047       100.0    NUMERIC
# 3                     f_week_sin1_a71d22f6    0.044632       100.0    NUMERIC
# 4                     f_week_cos1_d3d56d7f    0.029552       100.0    NUMERIC
# 5               f_weather_umap_48_66a91289    0.025132       100.0    NUMERIC
# 6               f_weather_umap_24_409427e4    0.019315       100.0    NUMERIC
# 7               f_weather_umap_33_b9760f68    0.014638       100.0    NUMERIC
# 8                     f_year_cos1_cd165f8c    0.012112       100.0    NUMERIC
# 9                     f_dow_jones_89547e1d    0.007461       100.0    NUMERIC
# 10              f_weather_umap_31_50ba2974    0.004600       100.0    NUMERIC
# 11                       f_silver_d4264cf9    0.004597       100.0    NUMERIC
# 12              f_weather_umap_43_4e9820c4    0.004291       100.0    NUMERIC
# 13              f_weather_umap_35_436c04a5    0.004104       100.0    NUMERIC
# 14               f_finance_umap_3_424d51ca    0.003752       100.0    NUMERIC
# 15                       f_snp500_61d23988    0.003303       100.0    NUMERIC
# 16                    f_cpi_pca_5_db7798a3    0.003016       100.0    NUMERIC
# 17  f_dow_jones_7d_to_7d_1y_shift_9628c89b    0.002820       100.0    NUMERIC
# 18                        f_stoxx_4ddb0c38    0.002752       100.0    NUMERIC
# 19          f_payment_fraud_score_b6a9c12e    0.002202       100.0    NUMERIC
# 20               f_italy_game_cnt_9cfcfe65    0.001993       100.0    NUMERIC
# 21                       f_nasdaq_d309709a    0.001855       100.0    NUMERIC
# 22              f_weather_umap_34_39fc3e94    0.001782       100.0    NUMERIC
# 23                 f_cbpol_umap_1_34dc2149    0.001578       100.0    NUMERIC
# 24                  f_cbpol_pca_3_2e94b9bf    0.001536       100.0    NUMERIC
# 25              f_silver_7d_to_1y_82c4ef86    0.001454       100.0    NUMERIC
# 26                 f_cbpol_umap_6_f175da9a    0.001432       100.0    NUMERIC
# 27       f_mlending_approve_score_d4c33397    0.001374       100.0    NUMERIC
# 28              f_weather_umap_45_b348f420    0.001316       100.0    NUMERIC
# 29     f_silver_7d_to_7d_1y_shift_ccbd2abf    0.001241       100.0    NUMERIC

# %%
model = CatBoostRegressor(verbose=False, allow_writing_files=False, random_state=0)
enricher.calculate_metrics(
    train_features, train_target,
    eval_set=[(test_features, test_target)], 
    estimator=model,
    scoring='mean_absolute_percentage_error'
)
# Out:
# Calculating metrics...
# Done
#         match_rate  baseline mean_absolute_percentage_error  \
#
# train        100.0                                 0.255844
# eval 1       100.0                                 0.243877
#
#         enriched mean_absolute_percentage_error    uplift
#
# train                                   0.16662  0.089224
# eval 1                                  0.13113  0.112746

# %%
enriched_train_features = enricher.transform(train_features, keep_input=True)
enriched_test_features = enricher.transform(test_features, keep_input=True)
enriched_train_features.head()
# Out:
# WARNING: You have started the search with the DATE key only. Try to add the COUNTRY and/or POSTAL_CODE keys to your dataset so that the search engine gets access to the additional data sources. Get details on https://github.com/upgini/upgini#2--choose-one-or-multiple-columns-as-a-search-keys
# 90.39637% of the rows are fully duplicated
# <table><tr><th style='font-weight:bold'>Column name</th><th style='font-weight:bold'>Status</th><th style='font-weight:bold'>Description</th></tr><tr><td>date</td><td style='background-color:#DAF7A6;color:black'>All valid</td><td>All values in this column are good to go</td></tr></table>
# Running search request with search_id=0b0e718f-ea48-4169-afc0-bae27a213fac
# We'll send email notification once it's completed, just use your personal api_key from profile.upgini.com
# Done
#
# Collecting selected features...
# Done
# WARNING: You have started the search with the DATE key only. Try to add the COUNTRY and/or POSTAL_CODE keys to your dataset so that the search engine gets access to the additional data sources. Get details on https://github.com/upgini/upgini#2--choose-one-or-multiple-columns-as-a-search-keys
# 90.36176% of the rows are fully duplicated
# <table><tr><th style='font-weight:bold'>Column name</th><th style='font-weight:bold'>Status</th><th style='font-weight:bold'>Description</th></tr><tr><td>date</td><td style='background-color:#DAF7A6;color:black'>All valid</td><td>All values in this column are good to go</td></tr></table>
# Running search request with search_id=ebe317b4-cb9c-4299-948b-5177ac63126b
# We'll send email notification once it's completed, just use your personal api_key from profile.upgini.com
# Done
#
# Collecting selected features...
# Done
#         date  f_cbpol_pca_3_2e94b9bf  f_cbpol_umap_1_34dc2149  \
# 0 2013-01-01               -0.323471                 4.815701
# 1 2013-01-01               -0.323471                 4.815701
# 2 2013-01-01               -0.323471                 4.815701
# 3 2013-01-01               -0.323471                 4.815701
# 4 2013-01-01               -0.323471                 4.815701
#
#    f_cbpol_umap_6_f175da9a  f_cpi_pca_5_db7798a3  \
# 0                 1.367325             -8.943169
# 1                 1.367325             -8.943169
# 2                 1.367325             -8.943169
# 3                 1.367325             -8.943169
# 4                 1.367325             -8.943169
#
#    f_dow_jones_7d_to_7d_1y_shift_9628c89b  f_dow_jones_89547e1d  \
# 0                                1.065267          13104.139648
# 1                                1.065267          13104.139648
# 2                                1.065267          13104.139648
# 3                                1.065267          13104.139648
# 4                                1.065267          13104.139648
#
#    f_finance_umap_3_424d51ca  f_italy_game_cnt_9cfcfe65  \
# 0                   7.647812                          0
# 1                   7.647812                          0
# 2                   7.647812                          0
# 3                   7.647812                          0
# 4                   7.647812                          0
#
#    f_mlending_approve_score_d4c33397  ...  f_weather_umap_34_39fc3e94  \
# 0                           0.338412  ...                    5.664261
# 1                           0.338412  ...                    5.664261
# 2                           0.338412  ...                    5.664261
# 3                           0.338412  ...                    5.664261
# 4                           0.338412  ...                    5.664261
#
#    f_weather_umap_35_436c04a5  f_weather_umap_43_4e9820c4  \
# 0                     4.76773                    5.079482
# 1                     4.76773                    5.079482
# 2                     4.76773                    5.079482
# 3                     4.76773                    5.079482
# 4                     4.76773                    5.079482
#
#    f_weather_umap_45_b348f420  f_weather_umap_48_66a91289  \
# 0                    4.923654                    4.540985
# 1                    4.923654                    4.540985
# 2                    4.923654                    4.540985
# 3                    4.923654                    4.540985
# 4                    4.923654                    4.540985
#
#    f_week_cos1_d3d56d7f  f_week_sin1_a71d22f6  f_year_cos1_cd165f8c  item  \
# 0               0.62349              0.781831               0.98522     5
# 1               0.62349              0.781831               0.98522     9
# 2               0.62349              0.781831               0.98522    33
# 3               0.62349              0.781831               0.98522    41
# 4               0.62349              0.781831               0.98522    24
#
#    store
# 0      7
# 1      4
# 2      1
# 3      3
# 4      5
#
# [5 rows x 31 columns]

# %%
model.fit(train_features, train_target)
preds = model.predict(test_features)
eval_metric(test_target.values, preds, 'SMAPE')
# Out:
# [37.65141857448004]

# %%
model.fit(enriched_train_features, train_target)
enriched_preds = model.predict(enriched_test_features)
eval_metric(test_target.values, enriched_preds, 'SMAPE')
# Out:
# [14.504497540797917]
